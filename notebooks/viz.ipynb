# %%
# imports
import pandas as pd 
import numpy as np 
import altair as alt

# %%
cust = pd.read_excel('../data_full/Customers.xlsx')
orders = pd.read_excel('../data_full/OrderInfo.xlsx')
lineitems = pd.read_csv('../data_full/LineItemSales.csv')
inventory = pd.read_csv('../data_full/Inventory.csv')

# %%
returns_df = pd.read_excel('../data_full/Ace_Bikes_Data.xlsx', usecols="AO:AP")
returns_df.columns = ['LineItemID', 'ReturnID']
returned_line_items = set(returns_df['LineItemID'].dropna().astype(int))

# %%
customer_order_df = cust.merge(
    orders,
    left_on='id',
    right_on='CustomerID',
    how='right'
)

customer_order_df = customer_order_df.drop(columns={'CustomerID'}).rename(columns={'id': 'CustomerID'})

# %%
lineitems["Date"] = pd.to_datetime(lineitems["Date"], errors="coerce")
customer_order_df["Date"] = pd.to_datetime(customer_order_df["Date"], errors="coerce")

# %%
customer_order_df.head()
# Out:
#    CustomerID first_name    last_name gender                  DOB  \
# 0       55582   Carmelle      Gittose      F  1982-08-03 00:00:00
# 1       55684       Wait      Grisard      M  1965-10-18 00:00:00
# 2       10174     Tobias    Johnstone      M  1956-03-09 00:00:00
# 3       19014      Daffi  Stallibrass      F  1983-05-10 00:00:00
# 4       18951    Cathryn        Sline      F  1956-10-09 00:00:00
#
#    LoyaltyMember  EmailList     Source LocationID       Date      Time  \
# 0            1.0        1.0     Social        L11 2021-12-30  17:42:00
# 1            1.0        1.0  Newspaper        L11 2021-12-30  11:33:00
# 2            0.0        1.0     Social        L02 2021-12-30  14:02:00
# 3            0.0        1.0     Social        L03 2021-12-30  14:01:00
# 4            0.0        1.0     Social        L03 2021-12-30  11:37:00
#
#    EmployeeID  OrderID
# 0          55    11672
# 1          55    11694
# 2           8    12293
# 3          16    13003
# ...

# %%
cust_yoy = (
    customer_order_df
    .dropna(subset=["Date"])  # avoid Year=NaN group
    .assign(Year=lambda df: df["Date"].dt.year)
    .groupby(["Year", "LocationID"], as_index=False)
    .agg(
        orders=("OrderID", "nunique"),
        customers=("CustomerID", "nunique"),
        rows=("CustomerID", "count"),
    )
)

sales_yoy = (
    lineitems
    .assign(Year=lineitems["Date"].dt.year)
    .groupby(["Year", "LocationID"], as_index=False)
    .agg(
        total_qty=("Qty", "sum"),
        line_items=("LineItemID", "count"),
        orders=("OrderID", "nunique"),
    )
)

sales_by_loc = (
    lineitems
    .groupby("LocationID", as_index=False)
    .agg(total_qty=("Qty", "sum"),
         line_items=("LineItemID", "count"),
         orders=("OrderID", "nunique"))
)

# %%
# YoY chart: line per location
chart = (
    alt.Chart(sales_yoy)
    .mark_line(point=True)
    .encode(
        x=alt.X("Year:O", title="Year"),
        y=alt.Y("total_qty:Q", title="Total Qty Sold"),
        color=alt.Color("LocationID:N", title="Location"),
        tooltip=[
            alt.Tooltip("Year:O", title="Year"),
            alt.Tooltip("LocationID:N", title="Location"),
            alt.Tooltip("total_qty:Q", title="Total Qty"),
            alt.Tooltip("orders:Q", title="Unique Orders"),
            alt.Tooltip("line_items:Q", title="Line Items"),
        ],
    )
    .properties(title="Year-over-Year Sales (Total Qty) by Location", width=650, height=350)
)

chart
# Out:
# alt.Chart(...)

# %%
chart = (
    alt.Chart(sales_by_loc)
    .mark_bar()
    .encode(
        x=alt.X("LocationID:N", title="Location"),
        y=alt.Y("total_qty:Q", title="Total Qty Sold"),
        tooltip=[
            alt.Tooltip("LocationID:N", title="Location"),
            alt.Tooltip("total_qty:Q", title="Total Qty"),
            alt.Tooltip("orders:Q", title="Unique Orders"),
            alt.Tooltip("line_items:Q", title="Line Items"),
        ],
    )
    .properties(title="Sales (Total Qty) by Location", width=500, height=300)
)

chart
# Out:
# alt.Chart(...)

# %% [markdown]
# ___
# NUMBER OF UNIQUE CUSTOMERS YEAR OVER YEAR
# ___

# %%
# YoY chart: number of orders by location
chart = (
    alt.Chart(cust_yoy)
    .mark_line(point=True)
    .encode(
        x=alt.X("Year:O", title="Year"),
        y=alt.Y("customers:Q", title="Unique Customers"),
        color=alt.Color("LocationID:N", title="Location"),
        tooltip=[
            alt.Tooltip("Year:O", title="Year"),
            alt.Tooltip("LocationID:N", title="Location"),
            alt.Tooltip("customers:Q", title="Unique Customers"),
            alt.Tooltip("orders:Q", title="Unique Orders"),
            alt.Tooltip("rows:Q", title="Rows"),
        ],
    )
    .properties(title="Year-over-Year Unique Customers by Location", width=650, height=350)
)
chart
# Out:
# alt.Chart(...)

# %% [markdown]
# ___
# NUMBER OF ORDERS YEAR OVER YEAR
# ___

# %%
# YoY chart: number of orders by location
chart = (
    alt.Chart(cust_yoy)
    .mark_line(point=True)
    .encode(
        x=alt.X("Year:O", title="Year"),
        y=alt.Y("orders:Q", title="Unique Orders"),
        color=alt.Color("LocationID:N", title="Location"),
        tooltip=[
            alt.Tooltip("Year:O", title="Year"),
            alt.Tooltip("LocationID:N", title="Location"),
            alt.Tooltip("customers:Q", title="Unique Customers"),
            alt.Tooltip("orders:Q", title="Unique Orders"),
            alt.Tooltip("rows:Q", title="Rows"),
        ],
    )
    .properties(title="Year-over-Year Unique Orders by Location", width=650, height=350)
)
chart
# Out:
# alt.Chart(...)

# %% [markdown]
# ___
# PLOT ECONOMICS
# ___

# %%
# ---- Item price and cost lookup ----
item_data = {
    1: (499.99, 225), 2: (629.99, 270), 3: (629.99, 270), 4: (499.99, 225),
    5: (599.99, 270), 6: (699.99, 315), 7: (999.99, 450), 8: (224.99, 100),
    9: (199.99, 90), 10: (199.99, 90), 11: (209.99, 95), 12: (209.99, 95),
    13: (214.99, 95), 14: (659.99, 300), 15: (599.99, 270), 16: (859.99, 380),
    17: (759.99, 340), 18: (999.99, 450), 19: (549.99, 240), 20: (499.99, 225),
    21: (999.99, 390), 22: (49.99, 20), 23: (15.99, 7), 24: (15.99, 7),
    25: (20.99, 7), 26: (649.99, 290), 27: (19.99, 9), 28: (39.99, 15),
    29: (29.99, 13), 30: (44.99, 20), 31: (49.99, 22), 32: (34.99, 15),
    33: (34.99, 15), 34: (44.99, 20), 35: (24.99, 11), 36: (199.99, 65),
    37: (44.99, 20), 38: (19.99, 9), 39: (34.99, 15), 40: (15.99, 5),
    41: (17.99, 5), 42: (29.99, 13), 43: (34.99, 15), 44: (34.99, 15),
    45: (44.99, 20), 46: (29.99, 10), 47: (24.99, 10), 48: (84.99, 35),
    49: (74.99, 35), 50: (54.99, 25), 51: (24.99, 11), 52: (499.99, 225),
    53: (10.99, 5), 54: (99.99, 35), 55: (29.99, 12.5),
}

# ---- Discount lookup ----
discount_map = {
    'D1': 0.20,
    'D2': 0.15,
    'D3': 0.10,
}

item_prices = {k: v[0] for k, v in item_data.items()}
item_costs = {k: v[1] for k, v in item_data.items()}

# %%
lineitems['UnitPrice'] = lineitems['ItemID'].map(item_prices)
lineitems['UnitCost'] = lineitems['ItemID'].map(item_costs)
lineitems['DiscountPct'] = lineitems['DiscountID'].map(discount_map).fillna(0.0)

lineitems['Revenue'] = lineitems['UnitPrice'] * lineitems['Qty'] * (1 - lineitems['DiscountPct'])
lineitems['Cost'] = lineitems['UnitCost'] * lineitems['Qty']
lineitems['Profit'] = lineitems['Revenue'] - lineitems['Cost']

lineitems['Date'] = pd.to_datetime(lineitems['Date'], errors='coerce')
lineitems['Year'] = lineitems['Date'].dt.year

# ---- Filter out returned line items ----
lineitem_clean = lineitems[~lineitems['LineItemID'].isin(returned_line_items)].copy()
lineitems = lineitem_clean.copy()

# %%
# ---- Aggregate across all locations by year ----
yearly_totals = (
    lineitems
    .groupby("Year", as_index=False)
    .agg(
        TotalRevenue=("Revenue", "sum"),
        TotalCost=("Cost", "sum"),
        TotalProfit=("Profit", "sum"),
    )
)

yearly_totals = yearly_totals.round(2)

# ---- Melt and plot ----
melted = yearly_totals.melt(
    id_vars=["Year"],
    value_vars=["TotalRevenue", "TotalCost", "TotalProfit"],
    var_name="Metric",
    value_name="Amount"
)

melted["Metric"] = melted["Metric"].replace({
    "TotalRevenue": "Revenue",
    "TotalCost": "Cost",
    "TotalProfit": "Profit"
})

# %%
# ---- Aggregate by Location and Year ----
summary = (
    lineitems
    .groupby(['Year', 'LocationID'], as_index=False)
    .agg(
        TotalRevenue=('Revenue', 'sum'),
        TotalCost=('Cost', 'sum'),
        TotalProfit=('Profit', 'sum'),
        TotalOrders=('OrderID', 'nunique'),
        TotalItems=('Qty', 'sum'),
    )
)

summary['TotalRevenue'] = summary['TotalRevenue'].round(2)
summary['TotalCost'] = summary['TotalCost'].round(2)
summary['TotalProfit'] = summary['TotalProfit'].round(2)

# %%
import altair as alt

# Melt summary into long format
melted = summary.melt(
    id_vars=["Year", "LocationID"],
    value_vars=["TotalRevenue", "TotalCost", "TotalProfit"],
    var_name="Metric",
    value_name="Amount"
)

melted["Metric"] = melted["Metric"].replace({
    "TotalRevenue": "Revenue",
    "TotalCost": "Cost",
    "TotalProfit": "Profit"
})

chart = (
    alt.Chart(melted)
    .mark_bar()
    .encode(
        x=alt.X("Year:O", title="Year"),
        y=alt.Y("Amount:Q", title="Amount ($)"),
        color=alt.Color("Metric:N", title="Metric",
                        scale=alt.Scale(domain=["Revenue", "Cost", "Profit"],
                                        range=["#4c78a8", "#e45756", "#54a24b"])),
        xOffset="Metric:N",
        tooltip=[
            "Year:O",
            "LocationID:N",
            "Metric:N",
            alt.Tooltip("Amount:Q", title="Amount", format="$,.2f"),
        ],
    )
    .properties(width=200, height=250)
    .facet(
        facet=alt.Facet("LocationID:N", title="Location"),
        columns=4
    )
    .properties(title="Revenue, Cost & Profit by Location (YoY)")
)

chart
# Out:
# alt.FacetChart(...)

# %%
chart = (
    alt.Chart(melted)
    .mark_bar()
    .encode(
        x=alt.X("Year:O", title="Year"),
        y=alt.Y("Amount:Q", title="Amount ($)"),
        color=alt.Color("Metric:N", title="Metric",
                        scale=alt.Scale(domain=["Revenue", "Cost", "Profit"],
                                        range=["#4c78a8", "#e45756", "#54a24b"])),
        xOffset="Metric:N",
        tooltip=[
            "Year:O",
            "Metric:N",
            alt.Tooltip("Amount:Q", title="Amount", format="$,.2f"),
        ],
    )
    .properties(title="Revenue, Cost & Profit Year over Year (All Locations)", width=650, height=400)
)

chart
# Out:
# alt.Chart(...)
